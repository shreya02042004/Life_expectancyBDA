# %% [markdown]
# <a href="https://colab.research.google.com/github/shreya02042004/Life_expectancyBDA/blob/main/practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
spam_amt = 0
print(spam_amt)

spam_amt=spam_amt+4
if spam_amt>0:
  print("i dont want spams today")

op= 'spam_amt' * 4
print(op)
# Out:
# 0
# i dont want spams today
# spam_amtspam_amtspam_amtspam_amt

# %%
print(max(5,8,9,2,4,0))
# Out:
# 9
